# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#データの読み込み
generated_track = pd.read_csv("Generated_track.csv",index_col=0)
minimonaco = pd.read_csv("minimonaco.csv",index_col=0)

# %%
plt.rcParams['font.family'] = "MS Gothic" # 日本語化の設定
generated_track.plot(figsize=(10,6))
# Out:
# <Axes: xlabel='Step'>

# %%
minimonaco.plot(figsize=(10,6))
# Out:
# <Axes: xlabel='Step'>
