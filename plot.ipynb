# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#データの読み込み
generated_track = pd.read_csv("Generated_track64.csv",index_col=0)
minimonaco = pd.read_csv("minimonaco.csv",index_col=0)

# %%
generated_track1= generated_track[["画像","VAE32"]]

# %%
plt.rcParams['font.family'] = "MS Gothic" # 日本語化の設定
generated_track1.plot(figsize=(10,6))
# Out:
# <Axes: xlabel='Step'>

# %%
minimonaco[["画像","VAEあり"]].plot(figsize=(10,6))
# Out:
# <Axes: xlabel='Step'>
